# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from scipy.interpolate import interp1d
from math import floor

# %matplotlib inline

# %%
#Macbeth
mwh = []
imwh = []

with open('white_n.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            mwh.append(float(row[0]))
            imwh.append(float(row[1]))
            line_count += 1
    print(line_count)

m1=[]
im1=[]    
with open('macbeth_dskin.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m1.append(float(row[0]))
            im1.append(float(row[1]))
            line_count += 1
    print(line_count)
    
    
m2=[]
im2=[]
with open('macbeth_2.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m2.append(float(row[0]))
            im2.append(float(row[1]))
            line_count += 1
    print(line_count)
    
m3=[]
im3=[]
with open('macbeth_3.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m3.append(float(row[0]))
            im3.append(float(row[1]))
            line_count += 1
    print(line_count)
    
m4=[]
im4=[]
with open('macbeth_4.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m4.append(float(row[0]))
            im4.append(float(row[1]))
            line_count += 1
    print(line_count)
    
m5=[]
im5=[]
with open('macbeth_5.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m5.append(float(row[0]))
            im5.append(float(row[1]))
            line_count += 1
    print(line_count)
    
m6=[]
im6=[]
with open('macbeth_6.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m6.append(float(row[0]))
            im6.append(float(row[1]))
            line_count += 1
    print(line_count)

m7=[]
im7=[]
with open('macbeth_7.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m7.append(float(row[0]))
            im7.append(float(row[1]))
            line_count += 1
    print(line_count)

m8=[]
im8=[]
with open('macbeth_8.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m8.append(float(row[0]))
            im8.append(float(row[1]))
            line_count += 1
    print(line_count)

m9=[]
im9=[]
with open('macbeth_9.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m9.append(float(row[0]))
            im9.append(float(row[1]))
            line_count += 1
    print(line_count)

m10=[]
im10=[]
with open('macbeth_10.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m10.append(float(row[0]))
            im10.append(float(row[1]))
            line_count += 1
    print(line_count)

m11=[]
im11=[]
with open('macbeth_11.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m11.append(float(row[0]))
            im11.append(float(row[1]))
            line_count += 1
    print(line_count)

m12=[]
im12=[]
with open('macbeth_12.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m12.append(float(row[0]))
            im12.append(float(row[1]))
            line_count += 1
    print(line_count)
    
m13=[]
im13=[]
with open('macbeth_13.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m13.append(float(row[0]))
            im13.append(float(row[1]))
            line_count += 1
    print(line_count)

m14=[]
im14=[]
with open('macbeth_14.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m14.append(float(row[0]))
            im14.append(float(row[1]))
            line_count += 1
    print(line_count)

m15=[]
im15=[]
with open('macbeth_15.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m15.append(float(row[0]))
            im15.append(float(row[1]))
            line_count += 1
    print(line_count)

m16=[]
im16=[]
with open('macbeth_16.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m16.append(float(row[0]))
            im16.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m17=[]
im17=[]
with open('macbeth_17.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m17.append(float(row[0]))
            im17.append(float(row[1]))
            line_count += 1  
    print(line_count)       

m18=[]
im18=[]
with open('macbeth_18.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m18.append(float(row[0]))
            im18.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m19=[]
im19=[]
with open('macbeth_19.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m19.append(float(row[0]))
            im19.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m20=[]
im20=[]
with open('macbeth_20.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m20.append(float(row[0]))
            im20.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m21=[]
im21=[]
with open('macbeth_21.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m21.append(float(row[0]))
            im21.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m22=[]
im22=[]
with open('macbeth_22.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m22.append(float(row[0]))
            im22.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m23=[]
im23=[]
with open('macbeth_23.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m23.append(float(row[0]))
            im23.append(float(row[1]))
            line_count += 1
    print(line_count)
     
m24=[]
im24=[]
with open('macbeth_24.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            m24.append(float(row[0]))
            im24.append(float(row[1]))
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are ï»¿W, I
# 379
# Column names are ï»¿wavelength, 1
# 62
# Column names are ï»¿wavelength, 2
# 62
# Column names are ï»¿wavelength, 3
# 62
# Column names are ï»¿wavelength, 4
# 62
# Column names are ï»¿wavelength, 5
# 62
# Column names are ï»¿wavelength, 6
# 62
# Column names are ï»¿wavelength, 7
# 62
# Column names are ï»¿wavelength, 8
# 62
# Column names are ï»¿wavelength, 9
# 62
# Column names are ï»¿wavelength, 10
# 62
# Column names are ï»¿wavelength, 11
# 62
# Column names are ï»¿wavelength, 12
# 62
# Column names are ï»¿wavelength, 13
# 62
# Column names are ï»¿wavelength, 14
# 62
# Column names are ï»¿wavelength, 15
# 62
# Column names are ï»¿wavelength, 16
# 62
# Column names are ï»¿wavelength, 17
# 62
# Column names are ï»¿wavelength, 18
# 62
# Column names are ï»¿wavelength, 19
# 62
# Column names are ï»¿wavelength, 20
# 62
# Column names are ï»¿wavelength, 21
# 62
# Column names are ï»¿wavelength, 22
# 62
# Column names are ï»¿wavelength, 23
# 62
# Column names are ï»¿wavelength, 24
# Processed 62 lines.

# %%
#Sensitivity Sony DXC 930
wale=[]
R=[]
G=[]
B=[]
with open('cam_s.txt') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            wale.append(float(row[0]))
            R.append(float(row[1]))
            G.append(float(row[2]))
            B.append(float(row[3]))
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are wl,  r,  g,  b
# Processed 77 lines.

# %%
nsenR = interp1d(wale, R, kind='cubic')
nsenG = interp1d(wale, G, kind='cubic')
nsenB = interp1d(wale, B, kind='cubic')

nwh = interp1d(mwh, imwh, kind='cubic')

# %%
senR = np.array(nsenR(mwh))
senG = np.array(nsenG(mwh))
senB = np.array(nsenB(mwh))

# %%
fig = plt.figure()
for i in range(1,25):
    nx = eval('m' + str(i))
    ny = eval('im' + str(i))
    nids = interp1d(nx,ny,kind='cubic')
    ids = np.array(nids(mwh))
    DR = floor(255*sum(np.multiply(np.multiply(imwh,ids),senR))/sum(np.multiply(imwh,senR)))
    DG = floor(255*sum(np.multiply(np.multiply(imwh,ids),senG))/sum(np.multiply(imwh,senG)))
    DB = floor(255*sum(np.multiply(np.multiply(imwh,ids),senB))/sum(np.multiply(imwh,senB)))
    
    if i>=1 and i<7:
        x=1.85
        if i==4 or i==1:
            x=4
    elif i>=7 and i<11:
        x=2
        if i==9:
            x=3
        if i==10:
            x=4.3
    elif i>=11 and i<13:
        x=1.68
    elif i>=13 and i<19:
        x=2.5
        if i==15:
            x=4.5
        if i==16:
            x=1.3
    else:
        x=1
    
    DR = DR*x
    DG = DG*x
    DB = DB*x
    
    fin = np.array([[[  DR,  DG,    DB],
        [DR,  DG,    DB]],

       [[  DR,  DG,    DB],
        [DR,  DG,    DB]]], dtype='uint8')
    
    
 
    globals()['sub%s' % i] = fig.add_subplot(4,6,i) # instead of plt.subplot(2, 2, 1)
    globals()['sub%s' % i].imshow(fin)
    globals()['sub%s' % i].axis('off')


plt.savefig('Macbeth_Recreate.png')
